# %%
0x2b8ced01320

# %%
dir(0x2b8ced01320)

# %%
print("Welcome to the STUDENT MANAGEMENT SYSTEM")
print("******************************************")
courses = ["pyton", "ml", "statics", "math", "ai", "c#"]
course_lenght = len(courses)
s_courses = []

namer=["Ramazan","Seda"]
surname=["KAVALCI","ÖZTÜRK"]

#Login step
print("You have 3 trial for login")
trial=1
while trial < 4:
   
    name = input("Enter your name:")
    lastname = input("Enter your last name:")
   
    for i in range(0,1,len(namer)+1):
        for j in range(0,1,len(surname)+1):
            if name==namer[i] and lastname==surname[j]:
                print("Welcome {} {}" .format(name,lastname))
                i+=1
                j+=1
                break
                
            else:
            
                print('Wrong trial.')
                print("{}. trial" .format(trial))
                trial += 1
    if trial == 4:
        print('FAILED!! Please try again later!')
        break
    

 
            
#Course selectiom
print("Please select min 3 courses and 5 max course in the list")
print("******************************************")
print(courses)
print("******************************************")
print("1", "2", "3", "4", "5", "6")

trial1 = 0
while trial1 < 5:
    course_s = int(input("Your course selection:"))
    
    
    if(course_s == 1):
        if ('pyton' in s_courses):
            print("\n *Pyton is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[0])
            print("\n=> {} added \n".format(courses[0]))
            print(s_courses)
            
    if(course_s == 2):
        if ('ml' in s_courses):
            print("\n *Ml is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[1])
            print("\n=> {} added \n".format(courses[1]))
            print(s_courses)
            
    if(course_s == 3):
        if ('statics' in s_courses):
            print("\n *Statics is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[2])
            print("\n=> {} added \n".format(courses[2]))
            print(s_courses)
            
    if(course_s == 4):
        if ('math' in s_courses):
            print("\n *Math is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[3])
            print("\n=> {} added \n".format(courses[3]))
            print(s_courses)
    
    if(course_s == 5):
        if ('ai' in s_courses):
            print("\n *AI is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[4])
            print("\n=> {} added \n".format(courses[4]))
            print(s_courses)
            
    if(course_s == 6):
        if ('c#' in s_courses):
            print("\n *C# is already selected")
            trial1 -= 1
        else:
            s_courses.append(courses[5])
            print("\n=> {} added \n".format(courses[5]))
            print(s_courses)
      
    trial1 += 1
    print("You have {} courses".format(len(s_courses)))

    if trial1 < 3:
        print("You must select at least 3 courses")
    if  trial1 >= 3 and trial1< 5:
        print("You can select max 5 courses")
    if trial1 == 5:
        print("Course Selection is completed")
        print("Your courses are {}" .format(s_courses))
        print("Please make your course selection to take an exam")
        course_exam = int(input("Your selection for exam:"))
        if (course_exam == 1):
            print("\n*You will take the exam of Python")
        if (course_exam == 2):
            print("\n*You will take the exam of ML")
    
        if (course_exam == 3):
            print("\n*You will take the exam of Statics")
        if (course_exam == 4):
            print("\n*You will take the exam of Math")
        if (course_exam == 5):
            print("\n*You will take the exam of AI")
        if (course_exam == 6):
            print("\n*You will take the exam of c#")

print("Enter your exam points:")

while True:
    try:
        mid = int(input('Midterm: '))
    except ValueError:
        print("Please enter your point as a number")
        exit(-1)
    if 0 < mid <=100:
        break
    else:
        print("You should enter the point between 1-100")

while True:
    try:
        project = int(input('Project: '))
    except ValueError:
        print("Please enter your point as a number")
        exit(-1)
    if 0 < project <=100:
        break
    else:
        print("You should enter the point between 1-100")

while True:
    try:
        final = int(input('Final: '))
    except ValueError:
        print("Please enter your point as a number")
        exit(-1)
    if 0 < final <=100:
        break
    else:
        print("You should enter the point between 1-100")

total_point =project * 0.2+ mid * 0.3 + final * 0.5
print("Total point is : {}".format(total_point))
if 90 <= total_point<=100:
    grade =print("Congrats!!! You passed this course with"+" "+"AA")
    print("CONGRATS! {} {}" .format(name,lastname))
    print("******************************************")
elif 70 <= total_point < 90:
    grade = print("Congrats!!! You passed this course with"+" "+"BB")
    print("CONGRATS! {} {}" .format(name,lastname))
    print("******************************************")
elif 50 < total_point <= 70:
    grade = print("Congrats!!! You passed this course with"+" "+"CC")
    print("CONGRATS! {} {}" .format(name,lastname))
    print("******************************************")
elif 30 < total_point <= 50:
    grade = print("Congrats!!! You passed this course with"+" "+"DD")
    print("CONGRATS! {} {}" .format(name,lastname))
    print("******************************************")
elif total_point<= 30:
    grade = print("FAILED for this course! with"+" "+"FF")
    print("SORRY! {} {}" .format(name,lastname))
    print("******************************************")
# Out:
# Welcome to the STUDENT MANAGEMENT SYSTEM
# ******************************************
# You have 3 trial for login
# Enter your name:rAMAZAN
# Enter your last name:D
# Wrong trial.
# 1. trial
# Enter your name:
# Enter your last name:G
# Wrong trial.
# 2. trial
# Enter your name:
# Enter your last name:G
# Wrong trial.
# 3. trial
# FAILED!! Please try again later!
# Please select min 3 courses and 5 max course in the list
# ******************************************
# ['pyton', 'ml', 'statics', 'math', 'ai', 'c#']
# ******************************************
# 1 2 3 4 5 6
# Your course selection:1
#
# => pyton added
#
# ['pyton']
# You have 1 courses
# You must select at least 3 courses
# Your course selection:2
#
# => ml added
#
# ['pyton', 'ml']
# You have 2 courses
# You must select at least 3 courses
# Your course selection:3
#
# => statics added
#
# ['pyton', 'ml', 'statics']
# You have 3 courses
# You can select max 5 courses
# Your course selection:4
#
# => math added
#
# ...

# %% [markdown]
# # """
#    if name ==s_name1 and lastname.upper()==s_lastname1:
#         print("Welcome {} {}" .format(name,lastname))
#         break
#     if  name ==s_name2 and lastname.upper()==s_lastname2:
#         print("Welcome {} {}" .format(name,lastname))
#         break
#     else:
#         print('Wrong trial.')
#         print("{}. trial" .format(trial))
#         trial += 1
#         if trial == 4:
#             print('FAILED!! Please try again later!')
#             sys.exit()
#
# """
